# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import cv2
import glob
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from tensorflow.keras.layers import Dense, Activation,Dropout,Conv2D, MaxPooling2D,BatchNormalization
import glob

# %%
labels=[]
for file in os.listdir('../input/fruit-recognition'):
    labels.append(file)

# %% [markdown]
# **Chúng ta có 15 nhãn để dự đoán,mỗi nhán tương ứng với 1 loại trái cây trong danh sách sau :**
#
# ['Orange', 'Pomegranate', 'Plum', 'Apple', 'Carambola', 'Guava', 'Kiwi', 'Pear', 'Persimmon', 'Tomatoes', 'muskmelon', 'Peach', 'Banana', 'Pitaya', 'Mango']
#
# Tiếp theo, ta sẽ gán nhãn cho từng loại trái cây

# %%
file_image=glob.glob('../input/fruit-recognition/'+'*/*/*.jpg')

# %%
labels
# Out:
# ['Orange',
#  'Pomegranate',
#  'Plum',
#  'Apple',
#  'Carambola',
#  'Guava',
#  'Kiwi',
#  'Pear',
#  'Persimmon',
#  'Tomatoes',
#  'muskmelon',
#  'Peach',
#  'Banana',
#  'Pitaya',
#  'Mango']

# %%
labels=np.array(labels)
labels

# %%
apple=len(os.listdir('../input/fruit-recognition/Apple/Total Number of Apples'))
carambola=len(os.listdir('../input/fruit-recognition/Carambola'))
pear=len(os.listdir('../input/fruit-recognition/Pear'))
plum=len(os.listdir('../input/fruit-recognition/Plum'))
Pomegra=len(os.listdir('../input/fruit-recognition/Pomegranate'))
a=apple+carambola+pear+plum+Pomegra
a
# Out:
# 14581

# %% [markdown]
# **Chuyển sang onehot encoding**

# %%
train = []
l=['2','3','4','5','6','7','8','b','c','d','e','f','g','m','n','p','w','x','y']
for j in labels:
    i=l.index(j)
    a=[]
    for r in range(15):
        if(r==i):
            a.append(1)
        else:
            a.append(0)
    a=np.array(a)
    train.append(a)
train=np.array(train)

# %%
for i,l in enumerate(labels):
    print(l)

# %%
y_t.shape

# %%
b={v:y_t[i] for i,v in enumerate(labels)}

# %%
img_path=

# %%
train = []
l=['Orange', 'Pomegranate', 'Plum', 'Apple', 'Carambola', 'Guava', 'Kiwi',
   'Pear', 'Persimmon', 'Tomatoes', 'muskmelon', 'Peach', 'Banana', 'Pitaya', 'Mango']
for j in y:
    i=l.index(j)
    a=[]
    for r in range(19):
        if(r==i):
            a.append(1)
        else:
            a.append(0)
    a=np.array(a)
    train.append(a)
train=np.array(train)  
train
